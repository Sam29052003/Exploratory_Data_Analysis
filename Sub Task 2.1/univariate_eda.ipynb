# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
df.describe()
# Out:
#           Order_ID  Customer_Age   Quantity    Unit_Price   Total_Sales
# count    15.000000     15.000000  15.000000     15.000000     15.000000
# mean   1008.000000     34.933333   2.666667  20473.333333  25360.000000
# std       4.472136      8.310636   1.759329  22330.583342  25566.043328
# min    1001.000000     23.000000   1.000000    700.000000   4000.000000
# 25%    1004.500000     28.500000   1.000000   1550.000000   4650.000000
# 50%    1008.000000     34.000000   2.000000   2500.000000   9200.000000
# 75%    1011.500000     40.000000   4.000000  38500.000000  40000.000000
# max    1015.000000     50.000000   6.000000  61000.000000  84000.000000

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object', 'category']).columns

num_cols, cat_cols
# Out:
# (Index(['Order_ID', 'Customer_Age', 'Quantity', 'Unit_Price', 'Total_Sales'], dtype='object'),
#  Index(['Order_Date', 'Gender', 'Product_Category', 'Region'], dtype='object'))

# %%
for col in num_cols:
    plt.figure()
    plt.hist(df[col], bins=30)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
for col in num_cols:
    plt.figure()
    sns.kdeplot(df[col], fill=True)
    plt.title(f"KDE Plot of {col}")
    plt.show()

# %%
for col in num_cols:
    plt.figure()
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
df[num_cols].skew()
# Out:
# Order_ID        0.000000
# Customer_Age    0.358451
# Quantity        0.588578
# Unit_Price      0.539814
# Total_Sales     1.035182
# dtype: float64

# %%
for col in cat_cols:
    print(f"\nValue Counts for {col}")
    print(df[col].value_counts())
# Out:
# Value Counts for Order_Date
# Order_Date
# 2023-01-05    1
# 2023-01-08    1
# 2023-01-10    1
# 2023-01-15    1
# 2023-01-20    1
# 2023-02-02    1
# 2023-02-05    1
# 2023-02-10    1
# 2023-02-14    1
# 2023-02-18    1
# 2023-03-01    1
# 2023-03-04    1
# 2023-03-09    1
# 2023-03-15    1
# 2023-03-20    1
# Name: count, dtype: int64
#
# Value Counts for Gender
# Gender
# Male      8
# Female    7
# Name: count, dtype: int64
#
# Value Counts for Product_Category
# Product_Category
# Electronics        4
# Clothing           3
# Home Appliances    3
# Beauty             3
# Sports             2
# Name: count, dtype: int64
#
# Value Counts for Region
# Region
# North    4
# West     4
# South    4
# East     3
# Name: count, dtype: int64

# %%
for col in cat_cols:
    plt.figure()
    df[col].value_counts().plot(kind='bar')
    plt.title(f"Bar Plot of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()
